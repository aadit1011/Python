# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# Specify the encoding to avoid UnicodeDecodeError
df = pd.read_csv('matches.csv', encoding='cp1252')

df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
winner=df.groupby('winner')

# %%
winner

# %%
len(df)
# Out:
# 636

# %%
len(winner)
# Out:
# 14

# %%
city=df.groupby('city')
len(city)
# Out:
# 30

# %%
df.groupby('city').size().sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# dtype: int64

# %%
df.groupby('city').first()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
df=pd.read_csv('matches.csv')
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df=pd.read_csv('deliveries.csv')
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
batsman=df.groupby(['batsman'])

# %%
# Top batsman.
top_batsman=batsman.sum(numeric_only=True).sort_values('batsman_runs',ascending=False)
top=top_batsman.head(5)
top[['batsman_runs']].plot(kind='bar')
# Out:
# <Axes: xlabel='batsman'>

# %%
top['batsman_runs']
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %%
total_balls_played_by_virat_kohli = batsman.get_group(('V Kohli')).shape[0]
total_balls_played_by_virat_kohli
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12148\3312842559.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   total_balls_played_by_virat_kohli = batsman.get_group(('V Kohli')).shape[0]
# 3494

# %% [markdown]
# Batman that scored most 4's in the series

# %%
# Batman that scored most 4's in the series

four=df.groupby('batsman_runs')
four=four.get_group(4)
four
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150403       636       2  Royal Challengers Bangalore
# 150407       636       2  Royal Challengers Bangalore
# 150418       636       2  Royal Challengers Bangalore
# 150447       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  \
# 2       Royal Challengers Bangalore     1     3      DA Warner
# 8       Royal Challengers Bangalore     2     2      DA Warner
# 13      Royal Challengers Bangalore     2     7   MC Henriques
# ...

# %%
maximum_four=four.groupby('batsman')
maximum_four

# %%
maximum=maximum_four.sum()
maximum
# Out:
#                 match_id  inning  \
# batsman
# A Ashish Reddy      7140      26
# A Chopra             708       7
# A Choudhary           30       1
# A Flintoff           605       8
# A Kumble             381       5
# ...                  ...     ...
# YK Pathan          78385     378
# YV Takawale         9336      42
# Yashpal Singh        686       8
# Yuvraj Singh       60068     298
# Z Khan              2391      15
#
#                                                      batting_team  \
# batsman
# A Ashish Reddy  Deccan ChargersDeccan ChargersDeccan ChargersS...
# A Chopra        Kolkata Knight RidersKolkata Knight RidersKolk...
# A Choudhary                           Royal Challengers Bangalore
# A Flintoff      Chennai Super KingsChennai Super KingsChennai ...
# A Kumble        Royal Challengers BangaloreRoyal Challengers B...
# ...                                                           ...
# YK Pathan       Kolkata Knight RidersKolkata Knight RidersKolk...
# ...

# %%
maximum_runs=maximum['batsman_runs']
maximum_runs
# Out:
# batsman
# A Ashish Reddy     64
# A Chopra           28
# A Choudhary         4
# A Flintoff         20
# A Kumble           12
#                  ...
# YK Pathan         960
# YV Takawale       104
# Yashpal Singh      20
# Yuvraj Singh      820
# Z Khan             44
# Name: batsman_runs, Length: 368, dtype: int64

# %%
fours=maximum_runs.sort_values(ascending=False)
fours=fours/4
fours
# Out:
# batsman
# G Gambhir         484.0
# SK Raina          402.0
# DA Warner         401.0
# S Dhawan          401.0
# V Kohli           384.0
#                   ...
# S Gopal             1.0
# DE Bollinger        1.0
# Sandeep Sharma      1.0
# Shivam Sharma       1.0
# KAJ Roach           1.0
# Name: batsman_runs, Length: 368, dtype: float64

# %%
fours.head(10)
# Out:
# batsman
# G Gambhir     484.0
# SK Raina      402.0
# DA Warner     401.0
# S Dhawan      401.0
# V Kohli       384.0
# RV Uthappa    377.0
# RG Sharma     354.0
# V Sehwag      334.0
# AM Rahane     320.0
# CH Gayle      297.0
# Name: batsman_runs, dtype: float64

# %% [markdown]
# Maximum 6

# %%
# Batman that scored most 6's in the series

six=df.groupby('batsman_runs')
six=six.get_group(6)
six
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150395       636       2  Royal Challengers Bangalore
# 150413       636       2  Royal Challengers Bangalore
# 150428       636       2  Royal Challengers Bangalore
# 150440       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball       batsman     non_striker  \
# 10      Royal Challengers Bangalore     2     4     DA Warner        S Dhawan
# 47      Royal Challengers Bangalore     8     4  MC Henriques        S Dhawan
# 75      Royal Challengers Bangalore    13     2  Yuvraj Singh    MC Henriques
# ...

# %%
maximum_six=six.groupby('batsman')
maximum_six

# %%
maximum=maximum_six.sum()
maximum
# Out:
#                  match_id  inning  \
# batsman
# A Ashish Reddy       7422      20
# A Choudhary             1       2
# A Flintoff            240       3
# A Mishra              657       9
# A Mithun              296       2
# ...                   ...     ...
# Y Venugopal Rao      7342      58
# YK Pathan           46220     256
# YV Takawale           705       5
# Yuvraj Singh        45082     202
# Z Khan                658       2
#
#                                                       batting_team  \
# batsman
# A Ashish Reddy   Deccan ChargersSunrisers HyderabadSunrisers Hy...
# A Choudhary                            Royal Challengers Bangalore
# A Flintoff                  Chennai Super KingsChennai Super Kings
# A Mishra         Delhi DaredevilsDelhi DaredevilsDelhi Daredevi...
# A Mithun                               Royal Challengers Bangalore
# ...                                                            ...
# ...

# %%
maximum_runs=maximum['batsman_runs']
maximum_runs
# Out:
# batsman
# A Ashish Reddy      90
# A Choudhary          6
# A Flintoff          12
# A Mishra            30
# A Mithun             6
#                   ...
# Y Venugopal Rao    222
# YK Pathan          894
# YV Takawale         18
# Yuvraj Singh       846
# Z Khan              12
# Name: batsman_runs, Length: 301, dtype: int64

# %%
sixes=maximum_runs.sort_values(ascending=False)
sixes=sixes/6
sixes
# Out:
# batsman
# CH Gayle         266.0
# SK Raina         174.0
# RG Sharma        173.0
# V Kohli          160.0
# DA Warner        160.0
#                  ...
# CK Langeveldt      1.0
# CR Woakes          1.0
# P Sahu             1.0
# DE Bollinger       1.0
# Basil Thampi       1.0
# Name: batsman_runs, Length: 301, dtype: float64

# %%
sixes.head(10)
# Out:
# batsman
# CH Gayle          266.0
# SK Raina          174.0
# RG Sharma         173.0
# V Kohli           160.0
# DA Warner         160.0
# AB de Villiers    158.0
# MS Dhoni          156.0
# YK Pathan         149.0
# KA Pollard        148.0
# Yuvraj Singh      141.0
# Name: batsman_runs, dtype: float64

# %% [markdown]
# Maximmum 6's scored by Virat Kohli against team

# %%
data=df[(df['batting_team']=='Royal Challengers Bangalore') | (df['bowling_team']=='Royal Challengers Bangalore')]
data
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
virat_batting=data[data['batsman']=='V Kohli']
virat_batting
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
virat_kohli_matches=virat_batting.groupby('bowling_team')
virat_kohli_matches

# %%
virat_total_scores=virat_kohli_matches.sum()
virat_total_scores
# Out:
#                          match_id  inning  \
# bowling_team
# Chennai Super Kings        202247     850
# Deccan Chargers             51025     383
# Delhi Daredevils           185435     719
# Gujarat Lions               74886     188
# Kings XI Punjab            138499     459
# Kochi Tuskers Kerala        13888     104
# Kolkata Knight Riders      145970     590
# Mumbai Indians             119033     529
# Pune Warriors               33486     120
# Rajasthan Royals           100685     403
# Rising Pune Supergiant       1907     134
# Rising Pune Supergiants     76878     186
# Sunrisers Hyderabad        160352     447
#
#                                                               batting_team  \
# bowling_team
# Chennai Super Kings      Royal Challengers BangaloreRoyal Challengers B...
# Deccan Chargers          Royal Challengers BangaloreRoyal Challengers B...
# Delhi Daredevils         Royal Challengers BangaloreRoyal Challengers B...
# ...

# %%
runs_scored_by_virat=virat_total_scores['batsman_runs']
runs_scored_by_virat.sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %% [markdown]
# Creating Function for every batsman

# %%
# Function to get maximum runs scored by a batsman against different teams

batsman=input('Enter the name of the batsman')

def maximum_runs_scored_by_batsman(batsman):
    # Filter the DataFrame for the specific batsman
    data = df[df['batsman'] == batsman]
    
    # Group by 'bowling_team' and sum the 'batsman_runs'
    data_grouped = data.groupby('bowling_team').agg({'batsman_runs': 'sum'})
    
    # Sort the resulting Series in descending order of runs
    return data_grouped['batsman_runs'].sort_values(ascending=False)


# Example function call
print(maximum_runs_scored_by_batsman(batsman))
# Out:
# Enter the name of the batsman AB de Villiers
# bowling_team
# Mumbai Indians                 510
# Rajasthan Royals               485
# Kings XI Punjab                482
# Chennai Super Kings            374
# Sunrisers Hyderabad            313
# Kolkata Knight Riders          255
# Delhi Daredevils               247
# Gujarat Lions                  233
# Deccan Chargers                153
# Pune Warriors                  149
# Royal Challengers Bangalore    115
# Rising Pune Supergiants         84
# Kochi Tuskers Kerala            54
# Rising Pune Supergiant          32
# Name: batsman_runs, dtype: int64
