# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 


df=pd.read_csv('matches.csv')
df
# Out:
#       id  season       city        date  ...                                             venue          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  2017-04-05  ...         Rajiv Gandhi International Stadium, Uppal      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  2017-04-06  ...           Maharashtra Cricket Association Stadium   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  2017-04-07  ...            Saurashtra Cricket Association Stadium      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  2017-04-08  ...                            Holkar Cricket Stadium     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  2017-04-08  ...                             M Chinnaswamy Stadium              NaN              NaN     NaN
# ..   ...     ...        ...         ...  ...                                               ...              ...              ...     ...
# ...

# %%
df['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
# Top 5 team with highest wins

df['winner'].value_counts().head().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# winner of 2016 season
df.tail(1)[['winner']]
# Out:
#                   winner
# 635  Sunrisers Hyderabad

# %%
# Toss Decision pie chart

df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# Win Margins 

df['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Wins by wicket 

df['win_by_wickets'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Pandas Series

# %%
city=df['city'].value_counts()

# %%
city.index
# Out:
# Index(['Mumbai', 'Bangalore', 'Kolkata', 'Delhi', 'Hyderabad', 'Chennai',
#        'Chandigarh', 'Jaipur', 'Pune', 'Durban', 'Ahmedabad', 'Centurion',
#        'Visakhapatnam', 'Rajkot', 'Dharamsala', 'Johannesburg', 'Cape Town',
#        'Abu Dhabi', 'Ranchi', 'Port Elizabeth', 'Cuttack', 'Raipur', 'Sharjah',
#        'Kochi', 'Indore', 'Kanpur', 'Nagpur', 'Kimberley', 'East London',
#        'Bloemfontein'],
#       dtype='object', name='city')

# %%
city.values
# Out:
# array([85, 66, 61, 60, 49, 48, 46, 33, 32, 15, 12, 12, 11, 10,  9,  8,  7,
#         7,  7,  7,  7,  6,  6,  5,  5,  4,  3,  3,  3,  2], dtype=int64)

# %%
city.head()
# Out:
# city
# Mumbai       85
# Bangalore    66
# Kolkata      61
# Delhi        60
# Hyderabad    49
# Name: count, dtype: int64

# %%
city.tail()
# Out:
# city
# Kanpur          4
# Nagpur          3
# Kimberley       3
# East London     3
# Bloemfontein    2
# Name: count, dtype: int64

# %%
city['Nagpur']
# Out:
# 3

# %%
# Top 5 team with highest match played.

team1=df['team1'].value_counts()
team2=df['team2'].value_counts()

team=(team1+team2)
team.sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# Top 5 team with highest match played.
team3=team.sort_values(ascending=False)
team3.head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.sort_values('city')
# Out:
#       id  season       city        date                        team1  ... player_of_match                                venue          umpire1         umpire2  umpire3
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad  ...       AM Rahane                 Sheikh Zayed Stadium        BF Bowden  RK Illingworth      NaN
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab  ...  Sandeep Sharma                 Sheikh Zayed Stadium  HDPK Dharmasena  RK Illingworth      NaN
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore  ...        PV Tambe                 Sheikh Zayed Stadium  HDPK Dharmasena   C Shamshuddin      NaN
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings  ...        SK Raina                 Sheikh Zayed Stadium   RK Illingworth   C Shamshuddin      NaN
# ...

# %%
city.sort_index(ascending=True)
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# Name: count, dtype: int64

# %%
city.sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
city.sort_index(ascending=False)
# Out:
# city
# Visakhapatnam     11
# Sharjah            6
# Ranchi             7
# Rajkot            10
# Raipur             6
# Pune              32
# Port Elizabeth     7
# Nagpur             3
# Mumbai            85
# Kolkata           61
# Kochi              5
# Kimberley          3
# Kanpur             4
# Johannesburg       8
# Jaipur            33
# Indore             5
# Hyderabad         49
# East London        3
# Durban            15
# Dharamsala         9
# Delhi             60
# Cuttack            7
# Chennai           48
# Chandigarh        46
# Centurion         12
# Cape Town          7
# Bloemfontein       2
# Bangalore         66
# Ahmedabad         12
# Abu Dhabi          7
# Name: count, dtype: int64

# %%
df.sort_index(ascending=False)
# Out:
#       id  season       city        date  ...                                             venue          umpire1          umpire2 umpire3
# 635  636    2016  Bangalore  2016-05-29  ...                             M Chinnaswamy Stadium  HDPK Dharmasena     BNJ Oxenford     NaN
# 634  635    2016      Delhi  2016-05-27  ...                                  Feroz Shah Kotla        M Erasmus        CK Nandan     NaN
# 633  634    2016      Delhi  2016-05-25  ...                                  Feroz Shah Kotla        M Erasmus    C Shamshuddin     NaN
# 632  633    2016  Bangalore  2016-05-24  ...                             M Chinnaswamy Stadium     AK Chaudhary  HDPK Dharmasena     NaN
# 631  632    2016     Raipur  2016-05-22  ...  Shaheed Veer Narayan Singh International Stadium   A Nand Kishore     BNJ Oxenford     NaN
# ..   ...     ...        ...         ...  ...                                               ...              ...              ...     ...
# ...

# %%
df.sort_values('winner',ascending=False)
# Out:
#       id  season       city        date  ...                                      venue                umpire1       umpire2 umpire3
# 0      1    2017  Hyderabad  2017-04-05  ...  Rajiv Gandhi International Stadium, Uppal            AY Dandekar      NJ Llong     NaN
# 46    47    2017  Hyderabad  2017-05-08  ...  Rajiv Gandhi International Stadium, Uppal  KN Ananthapadmanabhan     M Erasmus     NaN
# 502  503    2014  Hyderabad  2014-05-20  ...  Rajiv Gandhi International Stadium, Uppal           AK Chaudhary      NJ Llong     NaN
# 488  489    2014      Delhi  2014-05-10  ...                           Feroz Shah Kotla           RM Deshpande  BNJ Oxenford     NaN
# 486  487    2014  Ahmedabad  2014-05-08  ...               Sardar Patel Stadium, Motera           AK Chaudhary      NJ Llong     NaN
# ..   ...     ...        ...         ...  ...                                        ...                    ...           ...     ...
# ...

# %%
df.sort_values(['city','winner'],ascending=False)
# Out:
#       id  season           city        date  ...                                              venue          umpire1         umpire2 umpire3
# 536  537    2015  Visakhapatnam  2015-04-22  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...   RK Illingworth     VA Kulkarni     NaN
# 612  613    2016  Visakhapatnam  2016-05-08  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...           S Ravi   C Shamshuddin     NaN
# 615  616    2016  Visakhapatnam  2016-05-10  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      CB Gaffaney       VK Sharma     NaN
# 624  625    2016  Visakhapatnam  2016-05-17  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      Nitin Menon   C Shamshuddin     NaN
# 628  629    2016  Visakhapatnam  2016-05-21  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  HDPK Dharmasena     Nitin Menon     NaN
# ...

# %%
df.sort_values(['city','date'],ascending=False)
# Out:
#       id  season           city        date  ...                                              venue          umpire1         umpire2 umpire3
# 628  629    2016  Visakhapatnam  2016-05-21  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  HDPK Dharmasena     Nitin Menon     NaN
# 624  625    2016  Visakhapatnam  2016-05-17  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      Nitin Menon   C Shamshuddin     NaN
# 622  623    2016  Visakhapatnam  2016-05-15  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      Nitin Menon       CK Nandan     NaN
# 618  619    2016  Visakhapatnam  2016-05-13  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  HDPK Dharmasena       CK Nandan     NaN
# 615  616    2016  Visakhapatnam  2016-05-10  ...  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      CB Gaffaney       VK Sharma     NaN
# ...

# %%
df.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  ... player_of_match                                venue          umpire1         umpire2  umpire3
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals  ...     JP Faulkner                 Sheikh Zayed Stadium        Aleem Dar    AK Chaudhary      NaN
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore  ...        PV Tambe                 Sheikh Zayed Stadium  HDPK Dharmasena   C Shamshuddin      NaN
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab  ...  Sandeep Sharma                 Sheikh Zayed Stadium  HDPK Dharmasena  RK Illingworth      NaN
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings  ...        SK Raina                 Sheikh Zayed Stadium   RK Illingworth   C Shamshuddin      NaN
# ...
