# %%
import pandas  as pd 
import numpy as np 



df=pd.read_csv('matches.csv',index_col=['id'])
df 
df.head()
# Out:
#     season       city        date                        team1  ...                                      venue         umpire1        umpire2 umpire3
# id                                                              ...
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  ...  Rajiv Gandhi International Stadium, Uppal     AY Dandekar       NJ Llong     NaN
# 2     2017       Pune  2017-04-06               Mumbai Indians  ...    Maharashtra Cricket Association Stadium  A Nand Kishore         S Ravi     NaN
# 3     2017     Rajkot  2017-04-07                Gujarat Lions  ...     Saurashtra Cricket Association Stadium     Nitin Menon      CK Nandan     NaN
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant  ...                     Holkar Cricket Stadium    AK Chaudhary  C Shamshuddin     NaN
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore  ...                      M Chinnaswamy Stadium             NaN            NaN     NaN
#
# ...

# %%
df.shape
# Out:
# (636, 17)

# %%
# What was the date of the match that took place in the city 'Pune' that took place between Mumbai Indians and Rising Pune Supergiant ?


pune=df[(df['city']=='Pune') & (df['team1']=='Mumbai Indians') & (df['team2']=='Rising Pune Supergiant') ]
pune
# Out:
#     season  city        date           team1                   team2  ... player_of_match                                    venue         umpire1  umpire2 umpire3
# id                                                                    ...
# 2     2017  Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant  ...       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore   S Ravi     NaN
#
# [1 rows x 17 columns]

# %%
# Metching Multiple columns at once 


df[['team1','team2','winner']]
# Out:
#                            team1                        team2                       winner
# id
# 1            Sunrisers Hyderabad  Royal Challengers Bangalore          Sunrisers Hyderabad
# 2                 Mumbai Indians       Rising Pune Supergiant       Rising Pune Supergiant
# 3                  Gujarat Lions        Kolkata Knight Riders        Kolkata Knight Riders
# 4         Rising Pune Supergiant              Kings XI Punjab              Kings XI Punjab
# 5    Royal Challengers Bangalore             Delhi Daredevils  Royal Challengers Bangalore
# ..                           ...                          ...                          ...
# 632             Delhi Daredevils  Royal Challengers Bangalore  Royal Challengers Bangalore
# 633                Gujarat Lions  Royal Challengers Bangalore  Royal Challengers Bangalore
# 634          Sunrisers Hyderabad        Kolkata Knight Riders          Sunrisers Hyderabad
# ...

# %%
# How many matches were played in the city 'Mumbai'?

mumbai=df[df['city']=='Mumbai']
mumbai.shape
# Out:
# (85, 17)

# %%
# What is the team name of the winner of the match played in 'Bangalore'?
team=df[df['city']=='Bangalore']
winner=team['winner']
winner.count()
winner=winner.to_numpy()
winner
# Out:
# array(['Royal Challengers Bangalore', 'Mumbai Indians',
#        'Rising Pune Supergiant', 'Gujarat Lions', 'Kings XI Punjab',
#        'Kolkata Knight Riders', 'Kolkata Knight Riders', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Chennai Super Kings',
#        'Kings XI Punjab', 'Mumbai Indians', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Royal Challengers Bangalore',
#        'Royal Challengers Bangalore', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Deccan Chargers',
#        'Royal Challengers Bangalore', 'Mumbai Indians', 'Mumbai Indians',
#        'Royal Challengers Bangalore', 'Royal Challengers Bangalore',
#        'Royal Challengers Bangalore', 'Royal Challengers Bangalore',
#        'Royal Challengers Bangalore', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
# ...

# %%
# Which city hosted the first match in the dataset (i.e., the first row)?

first=df.head(1)
first
# first=df['date'].min()
# first
# Out:
#     season       city        date                team1  ...                                      venue      umpire1   umpire2 umpire3
# id                                                      ...
# 1     2017  Hyderabad  2017-04-05  Sunrisers Hyderabad  ...  Rajiv Gandhi International Stadium, Uppal  AY Dandekar  NJ Llong     NaN
#
# [1 rows x 17 columns]

# %%
# List all the matches that were played in 'Kolkata'. 

kolkata=df[df['city']=='Kolkata']
kolkata
# Out:
#      season     city        date                    team1                        team2  ...  player_of_match         venue                umpire1          umpire2 umpire3
# id                                                                                      ...
# 11     2017  Kolkata  2017-04-13          Kings XI Punjab        Kolkata Knight Riders  ...        SP Narine  Eden Gardens             A Deshmukh         NJ Llong     NaN
# 14     2017  Kolkata  2017-04-15    Kolkata Knight Riders          Sunrisers Hyderabad  ...       RV Uthappa  Eden Gardens            AY Dandekar         NJ Llong     NaN
# 23     2017  Kolkata  2017-04-21    Kolkata Knight Riders                Gujarat Lions  ...         SK Raina  Eden Gardens            CB Gaffaney      Nitin Menon     NaN
# 27     2017  Kolkata  2017-04-23    Kolkata Knight Riders  Royal Challengers Bangalore  ...  NM Coulter-Nile  Eden Gardens            CB Gaffaney        CK Nandan     NaN
# ...

# %%
#  What was the result of the match played on '2017-04-13'?

match=df[df['date']=='2017-04-13']
match['winner']
# Out:
# id
# 11    Kolkata Knight Riders
# Name: winner, dtype: object

# %%
# Which team won the last match in the dataset? 

last=df.tail(1)
last['winner']
# Out:
# id
# 636    Sunrisers Hyderabad
# Name: winner, dtype: object

# %%
# Find the city where the match with match_id 25 was played.

df1=pd.read_csv('matches.csv')
city=df1[df1['id']==25]

city['city']
# Out:
# 24    Pune
# Name: city, dtype: object

# %%
# What was the date of the match where 'Kolkata Knight Riders' played against 'Royal Challengers Bangalore' where man of the match was 'RV Uthappa'? 

date=df[(df['team1']=='Kolkata Knight Riders') & (df['team2']=='Royal Challengers Bangalore')]
date=date[date['player_of_match']=='RV Uthappa']
date['date']
# Out:
# id
# 506    2014-05-22
# Name: date, dtype: object

# %%
# List all the matches where 'Chennai' played and won the match.  

chennai=df[(df['city']=='Chennai') & (df['winner']=='Chennai Super Kings')]
print(chennai)
chennai.count()
# Out:
#      season     city        date                        team1  ...                            venue          umpire1         umpire2 umpire3
# id                                                             ...
# 67     2008  Chennai  2008-04-23          Chennai Super Kings  ...  MA Chidambaram Stadium, Chepauk        DJ Harper  GA Pratapkumar     NaN
# 71     2008  Chennai  2008-04-26        Kolkata Knight Riders  ...  MA Chidambaram Stadium, Chepauk        BF Bowden  AV Jayaprakash     NaN
# 91     2008  Chennai  2008-05-10          Chennai Super Kings  ...  MA Chidambaram Stadium, Chepauk   AV Jayaprakash      BG Jerling     NaN
# 202    2010  Chennai  2010-03-31  Royal Challengers Bangalore  ...  MA Chidambaram Stadium, Chepauk       BG Jerling     RE Koertzen     NaN
# 206    2010  Chennai  2010-04-03          Chennai Super Kings  ...  MA Chidambaram Stadium, Chepauk      RE Koertzen       RB Tiffin     NaN
# ...

# %%
# How many matches took place in 'Delhi' and were won by 'Delhi Daredevils'?

delhi=df[(df['city']=='Delhi') & (df['winner']=='Delhi Daredevils')]
print(delhi)
delhi.count()
# Out:
#      season   city        date                team1                        team2  ...  player_of_match             venue                umpire1         umpire2 umpire3
# id                                                                                ...
# 15     2017  Delhi  2017-04-15     Delhi Daredevils              Kings XI Punjab  ...      CJ Anderson  Feroz Shah Kotla               YC Barde     Nitin Menon     NaN
# 39     2017  Delhi  2017-05-02  Sunrisers Hyderabad             Delhi Daredevils  ...   Mohammed Shami  Feroz Shah Kotla               YC Barde     Nitin Menon     NaN
# 41     2017  Delhi  2017-05-04        Gujarat Lions             Delhi Daredevils  ...          RR Pant  Feroz Shah Kotla              M Erasmus     Nitin Menon     NaN
# 51     2017  Delhi  2017-05-12     Delhi Daredevils       Rising Pune Supergiant  ...          KK Nair  Feroz Shah Kotla  KN Ananthapadmanabhan       CK Nandan     NaN
# ...

# %%
# Which team won the most matches in 'Mumbai'?

city_won_in_mumbai = []
won_in_mumbai = df[df['city'] == 'Mumbai'] 
value = won_in_mumbai['winner'].unique()    

for item in value:
    city_won_in_mumbai.append(item)


frequency = {}


for team in city_won_in_delhi: 
    frequency[team] = len(won_in_mumbai[won_in_mumbai['winner'] == team])



most_wins_team = max(frequency, key=frequency.get)
most_wins_team, frequency[most_wins_team]



most_wins_team = max(frequency, key=frequency.get)  
most_wins_value = frequency[most_wins_team]  

print(f"The team with the most wins in Mumbai is {most_wins_team} with {most_wins_value} wins.")
# Out:
# The team with the most wins in Mumbai is Mumbai Indians with 45 wins.

# %%
# What was the result of the match that took place on the latest date in the dataset?


latest=df['date'].max()

latest
# Out:
# '2017-05-21'

# %%
#  Find all matches where the winning margin was greater than 50 runs.

winning_rate=df[df['win_by_runs']>50]
winning_rate
# Out:
#      season            city        date  ...                umpire1          umpire2 umpire3
# id                                       ...
# 9      2017            Pune  2017-04-11  ...            AY Dandekar           S Ravi     NaN
# 15     2017           Delhi  2017-04-15  ...               YC Barde      Nitin Menon     NaN
# 27     2017         Kolkata  2017-04-23  ...            CB Gaffaney        CK Nandan     NaN
# 33     2017            Pune  2017-04-29  ...  KN Ananthapadmanabhan        M Erasmus     NaN
# 44     2017           Delhi  2017-05-06  ...            Nitin Menon        CK Nandan     NaN
# 60     2008       Bangalore  2008-04-18  ...              Asad Rauf      RE Koertzen     NaN
# 69     2008      Chandigarh  2008-04-25  ...              Aleem Dar        AM Saheba     NaN
# 101    2008          Jaipur  2008-05-17  ...              BF Bowden       SL Shastri     NaN
# 115    2008          Mumbai  2008-05-30  ...              BF Bowden      RE Koertzen     NaN
# ...

# %%
# Which team has won the most matches in the city 'Chennai'?

city_won_in_chennai = []
won_in_chennai = df[df['city'] == 'Chennai'] 
value = won_in_chennai['winner'].unique()    

for item in value:
    city_won_in_chennai.append(item)


frequency = {}


for team in city_won_in_delhi: 
    frequency[team] = len(won_in_chennai[won_in_chennai['winner'] == team])



most_wins_team = max(frequency, key=frequency.get)
most_wins_team, frequency[most_wins_team]



most_wins_team = max(frequency, key=frequency.get)  
most_wins_value = frequency[most_wins_team]  

print(f"The team with the most wins in Chennai is {most_wins_team} with {most_wins_value} wins.")
# Out:
# The team with the most wins in Chennai is Chennai Super Kings with 33 wins.

# %%
# How many matches were played in 'Hyderabad' and what were their dates? 

match_count_in_hyderabad=df[df['city']=='Hyderabad']
match_count_in_hyderabad.count()

match_count_in_hyderabad['date']
# Out:
# id
# 1      2017-04-05
# 6      2017-04-09
# 19     2017-04-17
# 21     2017-04-19
# 36     2017-04-30
# 43     2017-05-06
# 47     2017-05-08
# 59     2017-05-21
# 66     2008-04-22
# 68     2008-04-24
# 77     2008-05-01
# 80     2008-05-25
# 92     2008-05-11
# 102    2008-05-18
# 114    2008-05-27
# 236    2011-04-09
# 245    2011-04-14
# 249    2011-04-16
# 260    2011-04-24
# 275    2011-05-03
# 279    2011-05-05
# 286    2011-05-10
# 331    2012-05-10
# 359    2012-05-08
# 373    2012-05-18
# 376    2012-05-20
# 384    2013-04-05
# 388    2013-04-07
# 405    2013-04-19
# 423    2013-05-01
# 428    2013-05-04
# 435    2013-05-08
# 449    2013-05-17
# 453    2013-05-19
# 493    2014-05-12
# 496    2014-05-14
# 500    2014-05-18
# 503    2014-05-20
# 551    2015-05-02
# 564    2015-05-11
# 568    2015-05-15
# 572    2015-05-17
# 584    2016-04-16
# 588    2016-04-18
# 594    2016-04-23
# 598    2016-04-26
# 603    2016-04-30
# 610    2016-05-06
# 618    2016-05-12
# ...

# %%
# List all matches where the winning team chased the target successfully (i.e., won by wickets).

target_chased_successfully=df[df['win_by_runs']==0]
target_chased_successfully
# Out:
#      season           city        date                   team1  ...                                              venue          umpire1          umpire2 umpire3
# id                                                              ...
# 2      2017           Pune  2017-04-06          Mumbai Indians  ...            Maharashtra Cricket Association Stadium   A Nand Kishore           S Ravi     NaN
# 3      2017         Rajkot  2017-04-07           Gujarat Lions  ...             Saurashtra Cricket Association Stadium      Nitin Menon        CK Nandan     NaN
# 4      2017         Indore  2017-04-08  Rising Pune Supergiant  ...                             Holkar Cricket Stadium     AK Chaudhary    C Shamshuddin     NaN
# 6      2017      Hyderabad  2017-04-09           Gujarat Lions  ...          Rajiv Gandhi International Stadium, Uppal       A Deshmukh         NJ Llong     NaN
# ...

# %%
# What was the largest winning margin (by runs) for a match played in 'Ahmedabad'? 

largest_winning_margin=df[df['city']=='Ahmedabad']
largest_winning_margin['win_by_runs'].max()
# Out:
# 62

# %%
# Find the date and city of the matches with the lowest winning margin (by wickets). 



lowest_winning_margin=df['win_by_wickets'].min()
lowest_winning_margin

city_and_date=df[df['win_by_wickets']==lowest_winning_margin]
city_and_date
# Out:
#      season           city        date                        team1  ...                                              venue                umpire1        umpire2 umpire3
# id                                                                   ...
# 1      2017      Hyderabad  2017-04-05          Sunrisers Hyderabad  ...          Rajiv Gandhi International Stadium, Uppal            AY Dandekar       NJ Llong     NaN
# 5      2017      Bangalore  2017-04-08  Royal Challengers Bangalore  ...                              M Chinnaswamy Stadium                    NaN            NaN     NaN
# 9      2017           Pune  2017-04-11             Delhi Daredevils  ...            Maharashtra Cricket Association Stadium            AY Dandekar         S Ravi     NaN
# 14     2017        Kolkata  2017-04-15        Kolkata Knight Riders  ...                                       Eden Gardens            AY Dandekar       NJ Llong     NaN
# ...
