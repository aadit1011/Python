# %%
import pandas as pd 
import numpy as np 


df=pd.read_csv('matches.csv')
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df[['date','city','team1','team2','winner']].shape
# Out:
# (636, 5)

# %%
df['winner'].shape
# Out:
# (636,)

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.iloc[1:4]
# Out:
#    id  season    city        date                   team1  \
# 1   2    2017    Pune  2017-04-06          Mumbai Indians
# 2   3    2017  Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
# 3           0         Kings XI Punjab            0               6
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
df1=pd.read_csv('matches.csv',index_col=['id'])
df1
# Out:
#      season       city        date                        team1  \
# id
# 1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017       Pune  2017-04-06               Mumbai Indians
# 3      2017     Rajkot  2017-04-07                Gujarat Lions
# 4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 632    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    2016      Delhi  2016-05-27                Gujarat Lions
# 636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df1.iloc[:4]
# Out:
#     season       city        date                   team1  \
# id
# 1     2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06          Mumbai Indians
# 3     2017     Rajkot  2017-04-07           Gujarat Lions
# 4     2017     Indore  2017-04-08  Rising Pune Supergiant
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
#
#     result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# id
# 1   normal           0     Sunrisers Hyderabad           35               0
# 2   normal           0  Rising Pune Supergiant            0               7
# ...

# %%
df.iloc[:40:5,1:30]
# Out:
#     season       city        date                team1  \
# 0     2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 5     2017  Hyderabad  2017-04-09        Gujarat Lions
# 10    2017    Kolkata  2017-04-13      Kings XI Punjab
# 15    2017     Mumbai  2017-04-16        Gujarat Lions
# 20    2017  Hyderabad  2017-04-19  Sunrisers Hyderabad
# 25    2017     Rajkot  2017-04-23      Kings XI Punjab
# 30    2017    Kolkata  2017-04-28     Delhi Daredevils
# 35    2017  Hyderabad  2017-04-30  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 10        Kolkata Knight Riders        Kolkata Knight Riders         field
# 15               Mumbai Indians               Mumbai Indians         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# ...

# %%
# Retrieve the first match's entire row of data using iloc.

df.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
# Fetch the last match's entire row using iloc.

df.iloc[-1]
# Out:
# id                                         636
# season                                    2016
# city                                 Bangalore
# date                                2016-05-29
# team1                      Sunrisers Hyderabad
# team2              Royal Challengers Bangalore
# toss_winner                Sunrisers Hyderabad
# toss_decision                              bat
# result                                  normal
# dl_applied                                   0
# winner                     Sunrisers Hyderabad
# win_by_runs                                  8
# win_by_wickets                               0
# player_of_match                    BCJ Cutting
# venue                    M Chinnaswamy Stadium
# umpire1                        HDPK Dharmasena
# umpire2                           BNJ Oxenford
# umpire3                                    NaN
# Name: 635, dtype: object

# %%
# Get the match data from the 5th row using iloc.

df.iloc[4]
# Out:
# id                                           5
# season                                    2017
# city                                 Bangalore
# date                                2017-04-08
# team1              Royal Challengers Bangalore
# team2                         Delhi Daredevils
# toss_winner        Royal Challengers Bangalore
# toss_decision                              bat
# result                                  normal
# dl_applied                                   0
# winner             Royal Challengers Bangalore
# win_by_runs                                 15
# win_by_wickets                               0
# player_of_match                      KM Jadhav
# venue                    M Chinnaswamy Stadium
# umpire1                                    NaN
# umpire2                                    NaN
# umpire3                                    NaN
# Name: 4, dtype: object

# %%
# Fetch the team1 and team2 values from the 10th match using iloc. 

df[['team1','team2']].iloc[9]
# Out:
# team1    Sunrisers Hyderabad
# team2         Mumbai Indians
# Name: 9, dtype: object

# %%
# Get the city, venue, and date of the first match using iloc.   


df[['city','date','venue']].iloc[0]
# Out:
# city                                     Hyderabad
# date                                    2017-04-05
# venue    Rajiv Gandhi International Stadium, Uppal
# Name: 0, dtype: object

# %%
# Retrieve the player_of_match, winner, and toss_winner from the 20th match. 

df[['player_of_match','winner','toss_winner']].iloc[19]
# Out:
# player_of_match                       CH Gayle
# winner             Royal Challengers Bangalore
# toss_winner                      Gujarat Lions
# Name: 19, dtype: object

# %%
# Fetch the win_by_runs and win_by_wickets upto 15th match.

df[['win_by_runs','win_by_wickets']].iloc[:14]
# Out:
#     win_by_runs  win_by_wickets
# 0            35               0
# 1             0               7
# 2             0              10
# 3             0               6
# 4            15               0
# 5             0               9
# 6             0               4
# 7             0               8
# 8            97               0
# 9             0               4
# 10            0               8
# 11            0               4
# 12            0               7
# 13           17               0

# %%
# Get the match data from the 2nd to 5th matches using iloc.

df.iloc[1:5]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 1           0       Rising Pune Supergiant            0               7
# 2           0        Kolkata Knight Riders            0              10
# ...

# %%
# Fetch the umpire1 and umpire2 values for matches from rows 3 to 7. 

df[['umpire1','umpire2']].iloc[2:7]
# Out:
#         umpire1        umpire2
# 2   Nitin Menon      CK Nandan
# 3  AK Chaudhary  C Shamshuddin
# 4           NaN            NaN
# 5    A Deshmukh       NJ Llong
# 6   Nitin Menon      CK Nandan

# %%
# Retrieve all columns for the matches at rows 12, 14, and 16. 

df.iloc[11:16:2]
# Out:
#     id  season       city        date                        team1  \
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
#
#                   team2          toss_winner toss_decision  result  \
# 11       Mumbai Indians       Mumbai Indians         field  normal
# 13  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 15       Mumbai Indians       Mumbai Indians         field  normal
#
#     dl_applied                 winner  win_by_runs  win_by_wickets  \
# 11           0         Mumbai Indians            0               4
# 13           0  Kolkata Knight Riders           17               0
# 15           0         Mumbai Indians            0               6
#
#    player_of_match                  venue                umpire1  \
# 11      KA Pollard  M Chinnaswamy Stadium  KN Ananthapadmanabhan
# ...

# %%
# Get the date, city, venue, and player_of_match for every 10th match in the dataset.  

df[['date','city','venue','player_of_match']].iloc[::10]
# Out:
#            date       city                                      venue  \
# 0    2017-04-05  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 10   2017-04-13    Kolkata                               Eden Gardens
# 20   2017-04-19  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 30   2017-04-28    Kolkata                               Eden Gardens
# 40   2017-05-04      Delhi                           Feroz Shah Kotla
# ..          ...        ...                                        ...
# 590  2016-04-21     Rajkot     Saurashtra Cricket Association Stadium
# 600  2016-04-29       Pune    Maharashtra Cricket Association Stadium
# 610  2016-05-07  Bangalore                      M Chinnaswamy Stadium
# 620  2016-05-14    Kolkata                               Eden Gardens
# 630  2016-05-22    Kolkata                               Eden Gardens
#
#     player_of_match
# 0      Yuvraj Singh
# 10        SP Narine
# 20    KS Williamson
# 30        G Gambhir
# ...

# %%
# Fetch all details for the 10th, 20th, and 30th match using iloc. 

df.iloc[9:39:10]
# Out:
#     id  season       city        date                        team1  \
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 29  30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
#
#              team2     toss_winner toss_decision  result  dl_applied  \
# 9   Mumbai Indians  Mumbai Indians         field  normal           0
# 19   Gujarat Lions   Gujarat Lions         field  normal           0
# 29   Gujarat Lions   Gujarat Lions         field  normal           0
#
#                          winner  win_by_runs  win_by_wickets player_of_match  \
# 9                Mumbai Indians            0               4       JJ Bumrah
# 19  Royal Challengers Bangalore           21               0        CH Gayle
# 29                Gujarat Lions            0               7          AJ Tye
#
#                                      venue       umpire1        umpire2  \
# ...

# %%
# Retrieve the winner, player_of_match, and win_by_runs for matches at every 5th index using iloc. 

df[['winner','player_of_match','win_by_runs']].iloc[::5]
# Out:
#                           winner player_of_match  win_by_runs
# 0            Sunrisers Hyderabad    Yuvraj Singh           35
# 5            Sunrisers Hyderabad     Rashid Khan            0
# 10         Kolkata Knight Riders       SP Narine            0
# 15                Mumbai Indians          N Rana            0
# 20           Sunrisers Hyderabad   KS Williamson           15
# ..                           ...             ...          ...
# 615          Sunrisers Hyderabad         A Zampa            4
# 620        Kolkata Knight Riders       YK Pathan            0
# 625  Royal Challengers Bangalore         V Kohli           82
# 630        Kolkata Knight Riders       YK Pathan           22
# 635          Sunrisers Hyderabad     BCJ Cutting            8
#
# [128 rows x 3 columns]

# %%
# Extract all match information for rows from 50 to 100 using iloc. 

df.iloc[50:101]
# Out:
#       id  season        city        date                        team1  \
# 50    51    2017       Delhi  2017-05-12             Delhi Daredevils
# 51    52    2017      Kanpur  2017-05-13                Gujarat Lions
# 52    53    2017     Kolkata  2017-05-13               Mumbai Indians
# 53    54    2017        Pune  2017-05-14              Kings XI Punjab
# 54    55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# 55    56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 56    57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 57    58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 58    59    2017   Hyderabad  2017-05-21               Mumbai Indians
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 60    61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 61    62    2008       Delhi  2008-04-19             Rajasthan Royals
# ...

# %%
# Fetch the match information for every second match between rows 20 to 50 using iloc.  

df.iloc[20:51:2]
# Out:
#     id  season        city        date                        team1  \
# 20  21    2017   Hyderabad  2017-04-19          Sunrisers Hyderabad
# 22  23    2017     Kolkata  2017-04-21        Kolkata Knight Riders
# 24  25    2017        Pune  2017-04-22          Sunrisers Hyderabad
# 26  27    2017     Kolkata  2017-04-23        Kolkata Knight Riders
# 28  29    2017        Pune  2017-04-26       Rising Pune Supergiant
# 30  31    2017     Kolkata  2017-04-28             Delhi Daredevils
# 32  33    2017        Pune  2017-04-29       Rising Pune Supergiant
# 34  35    2017  Chandigarh  2017-04-30             Delhi Daredevils
# 36  37    2017      Mumbai  2017-05-01  Royal Challengers Bangalore
# 38  39    2017       Delhi  2017-05-02          Sunrisers Hyderabad
# 40  41    2017       Delhi  2017-05-04                Gujarat Lions
# 42  43    2017   Hyderabad  2017-05-06       Rising Pune Supergiant
# 44  45    2017   Bangalore  2017-05-07  Royal Challengers Bangalore
# ...

# %%
# Retrieve the team1 and team2 for the first 10 matches played in Hyderabad 

hyderabad=df[df['city']=='Hyderabad']
hyderabad[['team1','team2']].iloc[:10]
# Out:
#                      team1                        team2
# 0      Sunrisers Hyderabad  Royal Challengers Bangalore
# 5            Gujarat Lions          Sunrisers Hyderabad
# 18     Sunrisers Hyderabad              Kings XI Punjab
# 20     Sunrisers Hyderabad             Delhi Daredevils
# 35     Sunrisers Hyderabad        Kolkata Knight Riders
# 42  Rising Pune Supergiant          Sunrisers Hyderabad
# 46          Mumbai Indians          Sunrisers Hyderabad
# 58          Mumbai Indians       Rising Pune Supergiant
# 65         Deccan Chargers             Delhi Daredevils
# 67         Deccan Chargers             Rajasthan Royals

# %%
# Get the winner, win_by_runs, and win_by_wickets for the first 20 matches where Royal Challengers Bangalore played. 

rcb=df[(df['team1']=='Royal Challengers Bangalore') | (df['team2']=='Royal Challengers Bangalore')]
rcb[['winner','win_by_runs','win_by_wickets']].iloc[:20]
# Out:
#                          winner  win_by_runs  win_by_wickets
# 0           Sunrisers Hyderabad           35               0
# 4   Royal Challengers Bangalore           15               0
# 7               Kings XI Punjab            0               8
# 11               Mumbai Indians            0               4
# 16       Rising Pune Supergiant           27               0
# 19  Royal Challengers Bangalore           21               0
# 26        Kolkata Knight Riders           82               0
# 29                Gujarat Lions            0               7
# 32       Rising Pune Supergiant           61               0
# 36               Mumbai Indians            0               5
# 41              Kings XI Punjab           19               0
# 44        Kolkata Knight Riders            0               6
# 54  Royal Challengers Bangalore           10               0
# 59        Kolkata Knight Riders          140               0
# ...

# %%
# Fetch umpire1, umpire2, and umpire3 for all matches with a dl_applied value of 1. 

dl_applied=df[df['dl_applied']==1]
dl_applied[['umpire1','umpire2','umpire3']]
# Out:
#                    umpire1          umpire2  umpire3
# 56            AK Chaudhary      Nitin Menon      NaN
# 99          AV Jayaprakash      RE Koertzen      NaN
# 102              Asad Rauf      K Hariharan      NaN
# 119              MR Benson        SD Ranade      NaN
# 122              DJ Harper        SD Ranade      NaN
# 148              DJ Harper   TH Wijewardene      NaN
# 251            K Hariharan          AL Hill      NaN
# 280              Asad Rauf       PR Reiffel      NaN
# 290            RE Koertzen        RB Tiffin      NaN
# 488           RM Deshpande     BNJ Oxenford      NaN
# 536         RK Illingworth      VA Kulkarni      NaN
# 567           AK Chaudhary  HDPK Dharmasena      NaN
# 597            AY Dandekar        CK Nandan      NaN
# 620         A Nand Kishore     BNJ Oxenford      NaN
# 624            Nitin Menon    C Shamshuddin      NaN
# 625  KN Ananthapadmanabhan        M Erasmus      NaN

# %%
# Retrieve the entire data for matches where Mumbai Indians won and use iloc for specific rows.

mi=df[df['winner']=='Mumbai Indians']
mi.iloc[2:30]
# Out:
#       id  season            city        date                        team1  \
# 11    12    2017       Bangalore  2017-04-14  Royal Challengers Bangalore
# 15    16    2017          Mumbai  2017-04-16                Gujarat Lions
# 21    22    2017          Indore  2017-04-20              Kings XI Punjab
# 23    24    2017          Mumbai  2017-04-22               Mumbai Indians
# 33    34    2017          Rajkot  2017-04-29                Gujarat Lions
# 36    37    2017          Mumbai  2017-05-01  Royal Challengers Bangalore
# 43    44    2017           Delhi  2017-05-06               Mumbai Indians
# 52    53    2017         Kolkata  2017-05-13               Mumbai Indians
# 57    58    2017       Bangalore  2017-05-19        Kolkata Knight Riders
# 58    59    2017       Hyderabad  2017-05-21               Mumbai Indians
# 74    75    2008         Kolkata  2008-04-29        Kolkata Knight Riders
# 81    82    2008          Mumbai  2008-05-04               Mumbai Indians
# ...

# %%
# Get match data for rows corresponding to matches where the win_by_wickets is greater than 5 using iloc.  

greater=df[df['win_by_wickets']>5]
greater.iloc[2:30]
# Out:
#     id  season        city        date                        team1  \
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# 15  16    2017      Mumbai  2017-04-16                Gujarat Lions
# 21  22    2017      Indore  2017-04-20              Kings XI Punjab
# 24  25    2017        Pune  2017-04-22          Sunrisers Hyderabad
# 28  29    2017        Pune  2017-04-26       Rising Pune Supergiant
# 29  30    2017   Bangalore  2017-04-27  Royal Challengers Bangalore
# 30  31    2017     Kolkata  2017-04-28             Delhi Daredevils
# 34  35    2017  Chandigarh  2017-04-30             Delhi Daredevils
# 38  39    2017       Delhi  2017-05-02          Sunrisers Hyderabad
# ...

# %%
# Fetch the date, city, and winner for all matches where the toss_decision was "bat" using iloc. 

toss_decision=df[df['toss_decision']=='bat']
toss_decision[['date','city','winner']].iloc[:31]
# Out:
#           date        city                       winner
# 4   2017-04-08   Bangalore  Royal Challengers Bangalore
# 7   2017-04-10      Indore              Kings XI Punjab
# 14  2017-04-15       Delhi             Delhi Daredevils
# 17  2017-04-17       Delhi        Kolkata Knight Riders
# 20  2017-04-19   Hyderabad          Sunrisers Hyderabad
# 33  2017-04-29      Rajkot               Mumbai Indians
# 36  2017-05-01      Mumbai               Mumbai Indians
# 46  2017-05-08   Hyderabad          Sunrisers Hyderabad
# 50  2017-05-12       Delhi             Delhi Daredevils
# 54  2017-05-14       Delhi  Royal Challengers Bangalore
# 58  2017-05-21   Hyderabad               Mumbai Indians
# 60  2008-04-19  Chandigarh          Chennai Super Kings
# 61  2008-04-19       Delhi             Delhi Daredevils
# 62  2008-04-20      Mumbai  Royal Challengers Bangalore
# 63  2008-04-20     Kolkata        Kolkata Knight Riders
# 64  2008-04-21      Jaipur             Rajasthan Royals
# ...

# %%
# Retrieve the team1, team2, and player_of_match for matches that happened in 2017 and had more than 100 runs victory using iloc.

match2017=df[(df['date']>='2017-01-01') & (df['date']<'2018-01-01' )]
more_than_100=match2017[match2017['win_by_runs']>100]
more_than_100[['team1','team2','player_of_match']]
# Out:
#              team1             team2 player_of_match
# 43  Mumbai Indians  Delhi Daredevils     LMP Simmons

# %%
# Get the venue, city, date, and winner for the first 5 matches that Sunrisers Hyderabad won using iloc.

srh=df[df['winner']=='Sunrisers Hyderabad']
srh[['date','venue','city','winner']].iloc[:5]
# Out:
#           date                                              venue        city  \
# 0   2017-04-05          Rajiv Gandhi International Stadium, Uppal   Hyderabad
# 5   2017-04-09          Rajiv Gandhi International Stadium, Uppal   Hyderabad
# 18  2017-04-17          Rajiv Gandhi International Stadium, Uppal   Hyderabad
# 20  2017-04-19          Rajiv Gandhi International Stadium, Uppal   Hyderabad
# 31  2017-04-28  Punjab Cricket Association IS Bindra Stadium, ...  Chandigarh
#
#                  winner
# 0   Sunrisers Hyderabad
# 5   Sunrisers Hyderabad
# 18  Sunrisers Hyderabad
# 20  Sunrisers Hyderabad
# 31  Sunrisers Hyderabad

# %%
# Fetch the toss_winner, toss_decision, and winner for all matches where the winner is the same as toss_winner using iloc

same=df[df['toss_winner']==df['winner']]
same[['toss_winner','toss_decision','winner']]
# Out:
#                      toss_winner toss_decision                       winner
# 1         Rising Pune Supergiant         field       Rising Pune Supergiant
# 2          Kolkata Knight Riders         field        Kolkata Knight Riders
# 3                Kings XI Punjab         field              Kings XI Punjab
# 4    Royal Challengers Bangalore           bat  Royal Challengers Bangalore
# 5            Sunrisers Hyderabad         field          Sunrisers Hyderabad
# ..                           ...           ...                          ...
# 629                Gujarat Lions         field                Gujarat Lions
# 631  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 632  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 634          Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad           bat          Sunrisers Hyderabad
#
# [325 rows x 3 columns]

# %%
# Retrieve match data for rows corresponding to the top 10 matches with the highest win_by_runs values using iloc. 

sorted_values=df.sort_values(by='win_by_runs',ascending=False)

sorted_values.iloc[:10]
# Out:
#       id  season        city        date                        team1  \
# 43    44    2017       Delhi  2017-05-06               Mumbai Indians
# 619  620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015   Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013   Bangalore  2013-04-23  Royal Challengers Bangalore
# 295  296    2011  Dharamsala  2011-05-17              Kings XI Punjab
# 114  115    2008      Mumbai  2008-05-30             Rajasthan Royals
# 182  183    2010       Delhi  2010-03-17               Mumbai Indians
# 8      9    2017        Pune  2017-04-11             Delhi Daredevils
# 541  542    2015     Chennai  2015-04-25          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# ...
